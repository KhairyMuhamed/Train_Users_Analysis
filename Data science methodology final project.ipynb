# %% [markdown]
# ## Gather

# %%
import pandas as pd 
users=pd.read_csv('test_users.csv')
users_sessions=pd.read_csv('sessions.csv')

# %% [markdown]
# ## Assess

# %%
users
# Out:
#                id date_account_created  timestamp_first_active  \
# 0      5uwns89zht           2014-07-01          20140701000006
# 1      jtl0dijy2j           2014-07-01          20140701000051
# 2      xx0ulgorjt           2014-07-01          20140701000148
# 3      6c6puo6ix0           2014-07-01          20140701000215
# 4      czqhjk3yfe           2014-07-01          20140701000305
# ...           ...                  ...                     ...
# 62091  cv0na2lf5a           2014-09-30          20140930235232
# 62092  zp8xfonng8           2014-09-30          20140930235306
# 62093  fa6260ziny           2014-09-30          20140930235408
# 62094  87k0fy4ugm           2014-09-30          20140930235430
# 62095  9uqfg8txu3           2014-09-30          20140930235901
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN     FEMALE  35.0      facebook            0
# ...

# %%
users_sessions
# Out:
#            user_id              action action_type            action_detail  \
# 0       d1mm9tcy42              lookup         NaN                      NaN
# 1       d1mm9tcy42      search_results       click      view_search_results
# 2       d1mm9tcy42              lookup         NaN                      NaN
# 3       d1mm9tcy42      search_results       click      view_search_results
# 4       d1mm9tcy42              lookup         NaN                      NaN
# ...            ...                 ...         ...                      ...
# 135916  iltmd264ed                show        view             user_profile
# 135917  iltmd264ed                show        view             user_profile
# 135918  iltmd264ed                show        view             user_profile
# 135919  iltmd264ed                show        view                       p3
# 135920  iltmd264ed  social_connections        data  user_social_connections
#
#             device_type  secs_elapsed
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62096 entries, 0 to 62095
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       62096 non-null  object
#  1   date_account_created     62096 non-null  object
#  2   timestamp_first_active   62096 non-null  int64
#  3   date_first_booking       0 non-null      float64
#  4   gender                   62096 non-null  object
#  5   age                      33220 non-null  float64
#  6   signup_method            62096 non-null  object
#  7   signup_flow              62096 non-null  int64
#  8   language                 62096 non-null  object
#  9   affiliate_channel        62096 non-null  object
#  10  affiliate_provider       62096 non-null  object
#  11  first_affiliate_tracked  62076 non-null  object
#  12  signup_app               62096 non-null  object
#  13  first_device_type        62096 non-null  object
# ...

# %%
users_sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135921 entries, 0 to 135920
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        135267 non-null  object
#  1   action         134680 non-null  object
#  2   action_type    113427 non-null  object
#  3   action_detail  113427 non-null  object
#  4   device_type    135921 non-null  object
#  5   secs_elapsed   133939 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 6.2+ MB

# %%
users_sessions.isnull().sum()
# Out:
# user_id            654
# action            1241
# action_type      22494
# action_detail    22494
# device_type          0
# secs_elapsed      1982
# dtype: int64

# %%
users.isnull().sum()
# Out:
# id                             0
# date_account_created           0
# timestamp_first_active         0
# date_first_booking         62096
# gender                         0
# age                        28876
# signup_method                  0
# signup_flow                    0
# language                       0
# affiliate_channel              0
# affiliate_provider             0
# first_affiliate_tracked       20
# signup_app                     0
# first_device_type              0
# first_browser                  0
# dtype: int64

# %%
columns_doublicated = pd.Series(list(users_sessions) + list(users))
x=columns_doublicated[columns_doublicated.duplicated()]
x
# Out:
# Series([], dtype: object)

# %%
list(users_sessions)
# Out:
# ['user_id',
#  'action',
#  'action_type',
#  'action_detail',
#  'device_type',
#  'secs_elapsed']

# %%
list(users)
# Out:
# ['id',
#  'date_account_created',
#  'timestamp_first_active',
#  'date_first_booking',
#  'gender',
#  'age',
#  'signup_method',
#  'signup_flow',
#  'language',
#  'affiliate_channel',
#  'affiliate_provider',
#  'first_affiliate_tracked',
#  'signup_app',
#  'first_device_type',
#  'first_browser']

# %%
users[users['age'].isnull()]
# Out:
#                id date_account_created  timestamp_first_active  \
# 1      jtl0dijy2j           2014-07-01          20140701000051
# 2      xx0ulgorjt           2014-07-01          20140701000148
# 3      6c6puo6ix0           2014-07-01          20140701000215
# 4      czqhjk3yfe           2014-07-01          20140701000305
# 7      tkpq0mlugk           2014-07-01          20140701000649
# ...           ...                  ...                     ...
# 62086  u7lv3glv6y           2014-09-30          20140930234703
# 62090  8yvhec201j           2014-09-30          20140930235019
# 62092  zp8xfonng8           2014-09-30          20140930235306
# 62093  fa6260ziny           2014-09-30          20140930235408
# 62094  87k0fy4ugm           2014-09-30          20140930235430
#
#        date_first_booking     gender  age signup_method  signup_flow language  \
# 1                     NaN  -unknown-  NaN         basic            0       en
# ...

# %%
users.describe()
# Out:
#        timestamp_first_active  date_first_booking           age   signup_flow
# count            6.209600e+04                 0.0  33220.000000  62096.000000
# mean             2.014081e+13                 NaN     37.616677      7.813885
# std              8.024585e+07                 NaN     74.440647     11.254291
# min              2.014070e+13                 NaN      1.000000      0.000000
# 25%              2.014072e+13                 NaN     26.000000      0.000000
# 50%              2.014081e+13                 NaN     31.000000      0.000000
# 75%              2.014091e+13                 NaN     40.000000     23.000000
# max              2.014093e+13                 NaN   2002.000000     25.000000

# %%
users_sessions.describe()
# Out:
#        secs_elapsed
# count  1.339390e+05
# mean   2.151370e+04
# std    9.311135e+04
# min    0.000000e+00
# 25%    4.060000e+02
# 50%    1.387000e+03
# 75%    9.584000e+03
# max    1.796329e+06

# %%
users_sessions.sample(10)
# Out:
#            user_id          action action_type            action_detail  \
# 71093   hoe6sa4vm5    authenticate      submit                    login
# 3419    toga865pvz           index   -unknown-                -unknown-
# 26354   6k8ov8dr9k            show   -unknown-                -unknown-
# 68569   29tsz5d7l0           index        view      view_search_results
# 34138   yx2iipztu3  search_results       click      view_search_results
# 112512  lrnq12jgu6     personalize        data  wishlist_content_update
# 82753   50p8ha8a7k     collections   -unknown-                -unknown-
# 58862   8om84hokf9            show   -unknown-                -unknown-
# 97092   noy8mcqrss  search_results       click      view_search_results
# 8329    guj7f7sjve    ask_question      submit             contact_host
#
#                              device_type  secs_elapsed
# 71093                        Mac Desktop           NaN
# 3419                              iPhone         159.0
# ...

# %%
users.sample(10)
# Out:
#                id date_account_created  timestamp_first_active  \
# 20906  392h7e10yn           2014-07-30          20140730230440
# 25172  f66hix35us           2014-08-06          20140806013207
# 44594  6pc79w09qs           2014-09-02          20140902234042
# 21450  rxft49sh1d           2014-07-31          20140731183746
# 57274  z1tkir60s3           2014-09-23          20140923031928
# 50321  9rm2ni681b           2014-09-11          20140911210251
# 9021   lxc7r7op9r           2014-07-16          20140716214436
# 17091  aicjy86qpw           2014-07-25          20140725211104
# 12456  jlal1a6npv           2014-07-20          20140720234442
# 35984  fstlk2ujqj           2014-08-21          20140821113524
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 20906                 NaN  -unknown-   NaN         basic           23
# 25172                 NaN  -unknown-  19.0         basic            0
# ...

# %%
users[users.id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date_account_created, timestamp_first_active, date_first_booking, gender, age, signup_method, signup_flow, language, affiliate_channel, affiliate_provider, first_affiliate_tracked, signup_app, first_device_type, first_browser]
# Index: []

# %%
users_sessions[users_sessions.user_id.duplicated()]
# Out:
#            user_id              action action_type            action_detail  \
# 1       d1mm9tcy42      search_results       click      view_search_results
# 2       d1mm9tcy42              lookup         NaN                      NaN
# 3       d1mm9tcy42      search_results       click      view_search_results
# 4       d1mm9tcy42              lookup         NaN                      NaN
# 5       d1mm9tcy42      search_results       click      view_search_results
# ...            ...                 ...         ...                      ...
# 135916  iltmd264ed                show        view             user_profile
# 135917  iltmd264ed                show        view             user_profile
# 135918  iltmd264ed                show        view             user_profile
# 135919  iltmd264ed                show        view                       p3
# 135920  iltmd264ed  social_connections        data  user_social_connections
#
#             device_type  secs_elapsed
# ...

# %%
users_sessions.user_id.value_counts()
# Out:
# fsa2gw8kk4    1179
# jrqykh9y8x    1169
# g1nf1o6wku    1130
# b8meb8ctyi    1081
# 4cgolfx94c     976
#               ...
# ah2mvtfp74       1
# ezhh2qwtdk       1
# xpwykr9p20       1
# mr2chdr4vp       1
# clmnizbi6q       1
# Name: user_id, Length: 1967, dtype: int64

# %% [markdown]
# #### Quality
# ##### `users` table
# - Age values are considered integers not  floats.
# - Missing records in users table (62096 instead of 275547 )
# - Missing value in column 'date_first_booking' 186639 nan values
# - Missing value in column 'age' 116866 nan values
# - Missing value in column 'first_affiliate_tracked' 6085 nan values cant solve
# - Missing value in column 'country_destination' 62096 nan values cant solve
# ##### `users_sessions` table
# - Multiple records for all records
# - secs_elapsed is a integer not a float
# - Missing value in column 'user_id'
# - Missing value in column 'action' 36183 nan values
# - Missing value in column 'action_type' 456198 nan values
# - Missing value in column 'device_type' 1 nan values
# - Missing value in column 'secs_elapsed' 50836 nan values

# %% [markdown]
# #### Tidiness
# - total_secs_elapsed column should be part of the `users`table
# - action_type coloumn and action_details coloumn of the `users_sessions`table must be in one coloumn called action_type_details

# %% [markdown]
# ## Clean

# %%
users_clean=users.copy()
users_sessions_clean=users_sessions.copy()

# %% [markdown]
# ### Missing Data

# %% [markdown]
# #### `users`: Missing records (62096 instead of 275547 )

# %%
users_cut=pd.read_csv('train_users_2.csv')
users_clean=pd.concat([users_clean,users_cut],ignore_index=True)

# %%
users_clean.isnull().sum()
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         186639
# gender                          0
# age                        116866
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6085
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination         62096
# dtype: int64

# %% [markdown]
# ### Quality

# %% [markdown]
# #### age and secs_elapsed is a integer not a float

# %%
users_clean['age'] = users_clean['age'].fillna(47.145310)
users_clean['age']=users_clean['age'].astype(int)
users_clean
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       5uwns89zht           2014-07-01          20140701000006
# 1       jtl0dijy2j           2014-07-01          20140701000051
# 2       xx0ulgorjt           2014-07-01          20140701000148
# 3       6c6puo6ix0           2014-07-01          20140701000215
# 4       czqhjk3yfe           2014-07-01          20140701000305
# ...            ...                  ...                     ...
# 275542  zxodksqpep           2014-06-30          20140630235636
# 275543  mhewnxesx9           2014-06-30          20140630235719
# 275544  6o3arsjbb4           2014-06-30          20140630235754
# 275545  jh95kwisub           2014-06-30          20140630235822
# 275546  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender  age signup_method  signup_flow language  \
# 0                     NaN     FEMALE   35      facebook            0       en
# ...

# %%
users_sessions_clean['secs_elapsed']=users_sessions_clean['secs_elapsed'].fillna(2.097644e+04)
users_sessions_clean['secs_elapsed']=users_sessions_clean['secs_elapsed'].astype(int)
users_sessions_clean
# Out:
#            user_id              action action_type            action_detail  \
# 0       d1mm9tcy42              lookup         NaN                      NaN
# 1       d1mm9tcy42      search_results       click      view_search_results
# 2       d1mm9tcy42              lookup         NaN                      NaN
# 3       d1mm9tcy42      search_results       click      view_search_results
# 4       d1mm9tcy42              lookup         NaN                      NaN
# ...            ...                 ...         ...                      ...
# 135916  iltmd264ed                show        view             user_profile
# 135917  iltmd264ed                show        view             user_profile
# 135918  iltmd264ed                show        view             user_profile
# 135919  iltmd264ed                show        view                       p3
# 135920  iltmd264ed  social_connections        data  user_social_connections
#
#             device_type  secs_elapsed
# ...

# %%
users_clean=users_clean.sort_values(by='id')
users_clean=users_clean.set_index('id')
users_clean
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# 00023iyk9l           2014-05-14          20140514195452         2014-05-14
# 0005ytdols           2013-08-04          20130804222511                NaN
# 000guo2307           2012-07-27          20120727090102         2012-07-28
# 000wc9mlv3           2013-12-03          20131203135137         2014-08-20
# 0010k6l0om           2014-08-06          20140806032202                NaN
# ...                         ...                     ...                ...
# zzysuoqg6x           2014-01-08          20140108221010                NaN
# zzyt9q2s9k           2013-04-13          20130413195441                NaN
# zzywmcn0jv           2014-02-21          20140221160109                NaN
# zzyx3uud3s           2012-12-08          20121208185003                NaN
# zzzlylp57e           2014-06-11          20140611074639         2014-06-24
#
# ...

# %%
users_sessions_clean=users_sessions_clean.dropna()
users_sessions_clean
# Out:
#            user_id              action action_type            action_detail  \
# 1       d1mm9tcy42      search_results       click      view_search_results
# 3       d1mm9tcy42      search_results       click      view_search_results
# 5       d1mm9tcy42      search_results       click      view_search_results
# 7       d1mm9tcy42         personalize        data  wishlist_content_update
# 8       d1mm9tcy42               index        view      view_search_results
# ...            ...                 ...         ...                      ...
# 135916  iltmd264ed                show        view             user_profile
# 135917  iltmd264ed                show        view             user_profile
# 135918  iltmd264ed                show        view             user_profile
# 135919  iltmd264ed                show        view                       p3
# 135920  iltmd264ed  social_connections        data  user_social_connections
#
#             device_type  secs_elapsed
# ...

# %%
users_clean=users_clean.dropna()
users_clean
# Out:
#            date_account_created  timestamp_first_active date_first_booking  \
# id
# 00023iyk9l           2014-05-14          20140514195452         2014-05-14
# 000guo2307           2012-07-27          20120727090102         2012-07-28
# 000wc9mlv3           2013-12-03          20131203135137         2014-08-20
# 0012yo8hu2           2013-07-08          20130708174058         2014-03-25
# 001357912w           2013-02-27          20130227191802         2014-02-03
# ...                         ...                     ...                ...
# zzxlft4pc7           2013-07-09          20130709211236         2013-07-10
# zzxxl4cftb           2012-12-07          20121207044407         2012-12-07
# zzy7t0y9cm           2014-03-27          20140327185345         2014-03-29
# zzyq03wcsh           2012-09-10          20120910174942         2012-09-11
# zzzlylp57e           2014-06-11          20140611074639         2014-06-24
#
# ...

# %%
users_clean=users_clean.drop('date_account_created', axis=1)
users_clean=users_clean.drop('date_first_booking', axis=1)

# %%
users_sessions_clean=users_sessions_clean.sort_values(by='user_id')
users_sessions_clean
# Out:
#           user_id                 action action_type  \
# 28489  0035hobuyj         search_results       click
# 28799  0035hobuyj         search_results       click
# 28797  0035hobuyj         search_results       click
# 28795  0035hobuyj         search_results       click
# 28793  0035hobuyj         search_results       click
# ...           ...                    ...         ...
# 63297  zyh6qrhvrc                   show        view
# 63296  zyh6qrhvrc            personalize        data
# 63294  zyh6qrhvrc  ajax_refresh_subtotal       click
# 63303  zyh6qrhvrc            personalize        data
# 63099  zyh6qrhvrc  ajax_refresh_subtotal       click
#
#                      action_detail      device_type  secs_elapsed
# 28489          view_search_results      Mac Desktop           570
# 28799          view_search_results      Mac Desktop          7841
# 28797          view_search_results      Mac Desktop          6666
# ...

# %% [markdown]
# ### Tidiness

# %% [markdown]
# - total_secs_elapsed column should be part of the `users`table

# %%
users_clean
# Out:
#             timestamp_first_active     gender  age signup_method  signup_flow  \
# id
# 00023iyk9l          20140514195452  -unknown-   31         basic            0
# 000guo2307          20120727090102  -unknown-   47         basic            0
# 000wc9mlv3          20131203135137       MALE   40         basic            0
# 0012yo8hu2          20130708174058  -unknown-   47         basic           24
# 001357912w          20130227191802       MALE   38         basic            0
# ...                            ...        ...  ...           ...          ...
# zzxlft4pc7          20130709211236       MALE   35         basic            0
# zzxxl4cftb          20121207044407     FEMALE   30      facebook            0
# zzy7t0y9cm          20140327185345  -unknown-   47         basic            0
# zzyq03wcsh          20120910174942     FEMALE   37         basic            0
# zzzlylp57e          20140611074639  -unknown-   47         basic            0
#
# ...

# %%
users_sessions_clean.user_id.value_counts()
# Out:
# jrqykh9y8x    1009
# fsa2gw8kk4     952
# toga865pvz     866
# 4cgolfx94c     814
# cpnrn3qy4x     807
#               ...
# 277pfhdsnh       1
# i191habfg5       1
# t9cfaxtvs7       1
# xpwykr9p20       1
# qguocnjorw       1
# Name: user_id, Length: 1943, dtype: int64

# %%
temp=users_sessions_clean.groupby('user_id').sum()
temp
# Out:
#             secs_elapsed
# user_id
# 0035hobuyj       5410613
# 00s1ecz3b2        492667
# 01l5gtpaww         31500
# 033oexa2qw        907804
# 039664pl26       1293531
# ...                  ...
# zwgxv8daxs         50748
# zwupvalu42       2000364
# zxepsk5fy2        160276
# zyb9wrugt1        233542
# zyh6qrhvrc       7763818
#
# [1943 rows x 1 columns]

# %%
users_clean=temp.join(users_clean, rsuffix='temp')

# %%
users_clean
# Out:
#             secs_elapsed  timestamp_first_active  gender   age signup_method  \
# user_id
# 0035hobuyj       5410613            2.014010e+13  FEMALE  47.0         basic
# 00s1ecz3b2        492667            2.014010e+13    MALE  47.0         basic
# 01l5gtpaww         31500                     NaN     NaN   NaN           NaN
# 033oexa2qw        907804                     NaN     NaN   NaN           NaN
# 039664pl26       1293531            2.014010e+13  FEMALE  25.0         basic
# ...                  ...                     ...     ...   ...           ...
# zwgxv8daxs         50748            2.014010e+13    MALE  32.0      facebook
# zwupvalu42       2000364                     NaN     NaN   NaN           NaN
# zxepsk5fy2        160276            2.014011e+13    MALE  31.0         basic
# zyb9wrugt1        233542            2.014010e+13    MALE  47.0         basic
# zyh6qrhvrc       7763818                     NaN     NaN   NaN           NaN
#
# ...

# %%
users_clean=users_clean.dropna()
users_clean
# Out:
#             secs_elapsed  timestamp_first_active     gender   age  \
# user_id
# 0035hobuyj       5410613            2.014010e+13     FEMALE  47.0
# 00s1ecz3b2        492667            2.014010e+13       MALE  47.0
# 039664pl26       1293531            2.014010e+13     FEMALE  25.0
# 03jbozytmd        577495            2.014011e+13       MALE  27.0
# 03qbeknjp1       3550037            2.014010e+13  -unknown-  47.0
# ...                  ...                     ...        ...   ...
# zr52g89zhh        234330            2.014010e+13       MALE  34.0
# ztef080me0       3492933            2.014011e+13     FEMALE  25.0
# zwgxv8daxs         50748            2.014010e+13       MALE  32.0
# zxepsk5fy2        160276            2.014011e+13       MALE  31.0
# zyb9wrugt1        233542            2.014010e+13       MALE  47.0
#
#            signup_method  signup_flow language affiliate_channel  \
# user_id
# 0035hobuyj         basic          0.0       en         sem-brand
# ...

# %%
list(users_clean)
# Out:
# ['secs_elapsed',
#  'timestamp_first_active',
#  'gender',
#  'age',
#  'signup_method',
#  'signup_flow',
#  'language',
#  'affiliate_channel',
#  'affiliate_provider',
#  'first_affiliate_tracked',
#  'signup_app',
#  'first_device_type',
#  'first_browser',
#  'country_destination']

# %% [markdown]
# - action_type coloumn and action_details coloumn of the `users_sessions`table must be in one coloumn called action_type_details

# %%
users_sessions_clean['action_type_detail'] = users_sessions_clean['action_type'].str.cat(users_sessions_clean['action_detail'],sep=":::")

# %%
users_sessions_clean
# Out:
#           user_id                 action action_type  \
# 28489  0035hobuyj         search_results       click
# 28799  0035hobuyj         search_results       click
# 28797  0035hobuyj         search_results       click
# 28795  0035hobuyj         search_results       click
# 28793  0035hobuyj         search_results       click
# ...           ...                    ...         ...
# 63297  zyh6qrhvrc                   show        view
# 63296  zyh6qrhvrc            personalize        data
# 63294  zyh6qrhvrc  ajax_refresh_subtotal       click
# 63303  zyh6qrhvrc            personalize        data
# 63099  zyh6qrhvrc  ajax_refresh_subtotal       click
#
#                      action_detail      device_type  secs_elapsed  \
# 28489          view_search_results      Mac Desktop           570
# 28799          view_search_results      Mac Desktop          7841
# 28797          view_search_results      Mac Desktop          6666
# ...

# %%
users_sessions_clean=users_sessions_clean.drop('action_detail', axis=1)
users_sessions_clean=users_sessions_clean.drop('action_type', axis=1)
users_sessions_clean
# Out:
#           user_id                 action      device_type  secs_elapsed  \
# 28489  0035hobuyj         search_results      Mac Desktop           570
# 28799  0035hobuyj         search_results      Mac Desktop          7841
# 28797  0035hobuyj         search_results      Mac Desktop          6666
# 28795  0035hobuyj         search_results      Mac Desktop          1562
# 28793  0035hobuyj         search_results      Mac Desktop          2433
# ...           ...                    ...              ...           ...
# 63297  zyh6qrhvrc                   show  Windows Desktop         55000
# 63296  zyh6qrhvrc            personalize  Windows Desktop          2030
# 63294  zyh6qrhvrc  ajax_refresh_subtotal  Windows Desktop          1698
# 63303  zyh6qrhvrc            personalize  Windows Desktop          2836
# 63099  zyh6qrhvrc  ajax_refresh_subtotal  Windows Desktop          1935
#
#                         action_type_detail
# 28489          click:::view_search_results
# ...

# %% [markdown]
# ### cluster

# %%
users_clean=users_clean[users_clean.age!=0]
users_clean
# Out:
#             secs_elapsed  timestamp_first_active     gender   age  \
# user_id
# 0035hobuyj       5410613            2.014010e+13     FEMALE  47.0
# 00s1ecz3b2        492667            2.014010e+13       MALE  47.0
# 039664pl26       1293531            2.014010e+13     FEMALE  25.0
# 03jbozytmd        577495            2.014011e+13       MALE  27.0
# 03qbeknjp1       3550037            2.014010e+13  -unknown-  47.0
# ...                  ...                     ...        ...   ...
# zr52g89zhh        234330            2.014010e+13       MALE  34.0
# ztef080me0       3492933            2.014011e+13     FEMALE  25.0
# zwgxv8daxs         50748            2.014010e+13       MALE  32.0
# zxepsk5fy2        160276            2.014011e+13       MALE  31.0
# zyb9wrugt1        233542            2.014010e+13       MALE  47.0
#
#            signup_method  signup_flow language affiliate_channel  \
# user_id
# 0035hobuyj         basic          0.0       en         sem-brand
# ...

# %%
apart_of_data_set_to_clusster=pd.DataFrame()
apart_of_data_set_to_clusster['Age']=users_clean['age']
apart_of_data_set_to_clusster['Secs_elapsed']=users_clean['secs_elapsed']
apart_of_data_set_to_clusster.describe()
apart_of_data_set_to_clusster.info()
apart_of_data_set_to_clusster=apart_of_data_set_to_clusster.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 726 entries, 0035hobuyj to zyb9wrugt1
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           726 non-null    float64
#  1   Secs_elapsed  726 non-null    int32
# dtypes: float64(1), int32(1)
# memory usage: 14.2+ KB

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5).fit(apart_of_data_set_to_clusster)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[3.91910377e+01 5.98263217e+05]
#  [6.67083333e+01 4.94366231e+06]
#  [3.60000000e+01 1.26682795e+07]
#  [4.87533632e+01 2.37869105e+06]
#  [7.20000000e+01 2.60399660e+07]]

# %%
plt.scatter(apart_of_data_set_to_clusster['Age'], apart_of_data_set_to_clusster['Secs_elapsed'], c= kmeans.labels_.astype(float), s=50, alpha=10)
plt.scatter(centroids[:, 0], centroids[:, 1], c='green', s=50)
plt.show()

# %%
apart_of_data_set_to_clusster=apart_of_data_set_to_clusster[apart_of_data_set_to_clusster.Age <50]
kmeans = KMeans(n_clusters=5).fit(apart_of_data_set_to_clusster)
centroids = kmeans.cluster_centers_
plt.scatter(apart_of_data_set_to_clusster['Age'], apart_of_data_set_to_clusster['Secs_elapsed'], c= kmeans.labels_.astype(float), s=50, alpha=10)
plt.scatter(centroids[:, 0], centroids[:, 1], c='green', s=50)
plt.show()

# %%
centroids=kmeans.cluster_centers_
print(centroids)
# Out:
# [[3.38000000e+01 1.33360830e+07]
#  [3.55224719e+01 1.86339531e+06]
#  [3.59462687e+01 5.02844042e+05]
#  [3.51041667e+01 3.67172772e+06]
#  [3.66315789e+01 6.75480316e+06]]

# %%
apart_of_data_set_to_clusster.plot()

# %%
users_clean=users_clean[users_clean.age <50]

# %%
users_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 633 entries, 0035hobuyj to zyb9wrugt1
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   secs_elapsed             633 non-null    int32
#  1   timestamp_first_active   633 non-null    float64
#  2   gender                   633 non-null    object
#  3   age                      633 non-null    float64
#  4   signup_method            633 non-null    object
#  5   signup_flow              633 non-null    float64
#  6   language                 633 non-null    object
#  7   affiliate_channel        633 non-null    object
#  8   affiliate_provider       633 non-null    object
#  9   first_affiliate_tracked  633 non-null    object
#  10  signup_app               633 non-null    object
#  11  first_device_type        633 non-null    object
#  12  first_browser            633 non-null    object
# ...

# %%
users_clean.plot(x='timestamp_first_active',y='secs_elapsed',kind='scatter')

# %%
users_clean.plot(x='age',y='secs_elapsed',kind='scatter')

# %%
users_clean.plot(x='signup_flow',y='secs_elapsed',kind='scatter')

# %%
users_clean.plot(x='timestamp_first_active',y='age',kind='scatter')

# %%
users_clean.plot(x='timestamp_first_active',y='signup_flow',kind='scatter')

# %%
users_clean.describe()
# Out:
#        secs_elapsed  timestamp_first_active         age  signup_flow
# count  6.330000e+02            6.330000e+02  633.000000   633.000000
# mean   1.655047e+06            2.014010e+13   35.703002     2.952607
# std    1.854452e+06            1.910933e+06    8.580977     6.997805
# min    6.000000e+02            2.014010e+13   18.000000     0.000000
# 25%    4.610930e+05            2.014010e+13   28.000000     0.000000
# 50%    1.082691e+06            2.014010e+13   34.000000     0.000000
# 75%    2.296402e+06            2.014011e+13   47.000000     0.000000
# max    1.499617e+07            2.014011e+13   49.000000    25.000000

# %%
users_clean.secs_elapsed.hist()

# %%
users_clean.timestamp_first_active.hist()

# %%
users_clean.age.hist()

# %%
users_clean.plot(x='secs_elapsed',y='timestamp_first_active',kind='box')

# %%
users_clean.plot(x='secs_elapsed',y='age',kind='box')

# %%
users_clean.plot(x='secs_elapsed',y='signup_flow',kind='box')

# %%
users_clean.plot(x='timestamp_first_active',y='age',kind='box')

# %%
users_clean.plot(x='timestamp_first_active',y='signup_flow',kind='box')

# %%
users_clean.plot(x='age',y='signup_flow',kind='box')

# %%
finally_clean_data= users_clean.to_csv('finally_clean_data.csv', index = True)

# %%
finally_clean_data
